# %% [markdown]
# MathNation Data Exploration
# ===
# Exploring a sample of anonymized MathNation data.

# %%
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_dir = Path("../data")
assert data_dir.exists()

# %%
mn_discussion_filepath = data_dir / "raw" / "math_nation" / "mn_discussion_20230914.csv"
assert mn_discussion_filepath.exists()
mn_df = pd.read_csv(mn_discussion_filepath)
mn_df.shape
# Out:
# (152844, 9)

# %%
mn_df.sample(3)
# Out:
#         reply_id  reply_user  \
# 89529    2468990     1412702
# 145191    974764      667659
# 62185    1172038      681091
#
#                                             reply_content  \
# 89529                                            Examples
# 145191                             MAFS Section 1 video 6
# 62185   Jack, lets see! Lets multiply those to see if ...
#
#            reply_ts_created  post_id subject_name  \
# 89529   2018-03-13 17:18:45  2468982    Algebra 1
# 145191  2015-10-13 21:25:03   974748    Algebra 1
# 62185   2016-01-30 21:49:40  1172013    Algebra 1
#
#                                              post_content  post_user  \
# 89529                 degree and terms of a polynomial?\n    7395540
# 145191  Is there any videos on multiplying and dividin...    2252406
# 62185   Help! solve each equation and check for soluti...    3584741
#
#             post_ts_created
# 89529   2018-03-13 17:15:02
# 145191  2015-10-13 21:23:07
# 62185   2016-01-30 21:40:17

# %%
mn_df.groupby("post_id").subject_name.head(1).value_counts()
# Out:
# subject_name
# Algebra 1         15943
# Geometry            133
# Pre-Algebra          24
# 8th Grade Math        1
# 6th Grade Math        1
# Name: count, dtype: int64

# %%
# for row in mn_df[mn_df.subject_name == "Pre-Algebra"].drop_duplicates(subset="post_id", keep="first").itertuples():
#    print(row.post_content)

# %%
# manually extracted student queries that are relevant for testing
prealgebra_student_queries = [
    "What is the quotient rule??",
    "How do I multiply fractions???????",
    "How do you multiply fractions?!?!?",
]

# %%
first_reply_df = mn_df.sort_values(by=["post_id", "reply_ts_created"]).drop_duplicates(subset="post_id", keep="first")
is_extended_post = first_reply_df.reply_user == first_reply_df.post_user
is_extended_post.sum() / len(first_reply_df)
# Out:
# 0.08228791454477705

# %%
first_reply_df[is_extended_post]
# Out:
#        reply_id  reply_user                   reply_content  \
# 84643      1867      945440           someone please help\n
# 2633       2065      939329     Can somebody help me please
# 50640      3277      572466                      need  help
# 37363      3487     1032512                     Any takers?
# 6423       3733      524723     how would you solve this?\n
# ...         ...         ...                             ...
# 1252    3305954     4599973                           *part
# 26794   3306558     5197522  i think it is but i dont now\n
# 74748   3308394     5223632               here is the paper
# 36997   3312002     4519295                        anybody?
# 41571   3320636     4807952               How do I do this,
#
#           reply_ts_created  post_id subject_name  \
# 84643  2013-10-22 23:35:31     1865    Algebra 1
# 2633   2013-10-23 01:08:46     2045    Algebra 1
# 50640  2013-10-26 17:33:16     3276    Algebra 1
# 37363  2013-10-28 01:49:26     3485    Algebra 1
# 6423   2013-10-28 22:52:32     3732    Algebra 1
# ...                    ...      ...          ...
# 1252   2021-09-11 21:17:51  3305953     Geometry
# 26794  2021-09-13 20:59:33  3306554    Algebra 1
# 74748  2021-09-15 23:05:46  3308391    Algebra 1
# 36997  2021-09-21 23:51:27  3311997    Algebra 1
# 41571  2021-10-12 23:10:24  3320632    Algebra 1
#
#                                             post_content  post_user  \
# 84643                                                NaN     945440
# 2633            If 9a+6b+8c=−3 ,\n\nwhat is 54a+48c+36b?     939329
# 50640                            \ny + 2x = −1\n3y − x =     572466
# 37363  Challenge problem! Suppose the polynomial:\n\n...    1032512
# 6423                                                 NaN     524723
# ...                                                  ...        ...
# 1252         May someone please help me with let b and c    4599973
# 26794  If the question has a&lt;25 is a&lt;=25 the sa...    5197522
# 74748          for the first box I got x&gt;0 and x&lt;6    5223632
# 36997                                               help    4519295
# 41571                              Can somebody help me?    4807952
#
#            post_ts_created
# 84643  2013-10-22 23:35:14
# 2633   2013-10-23 01:03:49
# 50640  2013-10-26 17:32:44
# 37363  2013-10-28 01:27:00
# 6423   2013-10-28 22:52:14
# ...                    ...
# 1252   2021-09-11 21:17:40
# 26794  2021-09-13 20:58:48
# 74748  2021-09-15 23:05:04
# 36997  2021-09-21 23:49:09
# 41571  2021-10-12 23:08:45
#
# [1325 rows x 9 columns]

# %%
posts = []
for post_id, group in mn_df.sort_values(by=["post_id", "reply_ts_created"]).groupby("post_id"):
    post_content = str(group.iloc[0].post_content)
    post_user = group.iloc[0].post_user
    for row in group.itertuples():
        if row.reply_user != post_user:
            break  # reply from non-OP
        else:
            # continuation of the post in a reply
            post_content += "\n[Continued:] " + str(row.reply_content)
        prev_row = row
    posts.append(
        {
            "post_id": post_id,
            "post_user": post_user,
            "subject_name": group.iloc[0].subject_name,
            "post_ts_created": group.iloc[0].post_ts_created,
            "post_content": post_content,
        }
    )
len(posts)
# Out:
# 16102

# %%
pd.DataFrame(posts).sample(3)
# Out:
#        post_id  post_user subject_name      post_ts_created  \
# 3777    706733    1218779    Algebra 1  2015-04-09 21:51:42
# 11824  2261468    3440812    Algebra 1  2017-10-31 13:47:47
# 3957    739247    2647012    Algebra 1  2015-04-18 15:51:10
#
#                                             post_content
# 3777   what is 5349 to the third power equal???? HELP...
# 11824  =| =] =) =} ^o^ ^0^ ^@^ ^u^ all mojys are not ...
# 3957                            Melissa who's  after ya?

# %%
pd.DataFrame(posts).to_csv(data_dir / "derived" / "mn_student_queries_raw3.csv")

# %% [markdown]
# Original sample used for annotation was this:
#
# ```
# sdf = mn_df[mn_df.subject_name.isin(["Algebra 1", "Geometry"])]
# sdf = sdf.drop_duplicates(subset="post_id", keep="first")
# sdf[["post_id", "subject_name", "post_content", "post_user", "post_ts_created"]].to_csv(data_dir / "derived" / "mn_student_queries_raw.csv")
# ```
#
# But I threw those annotations away.

# %% [markdown]
# ### Loading annotated data

# %%
adf = pd.read_csv(data_dir / "derived" / "mn_student_queries_raw2_annotated.csv")
adf.shape
# Out:
# (553, 8)

# %%
adf.sample(n=3)
# Out:
#      index  post_id  post_user subject_name      post_ts_created  \
# 2        2    19856     848987    Algebra 1  2013-11-16 23:25:43
# 462    462  3119582    3073615     Geometry  2020-03-31 19:38:40
# 405    405  2966682    8261996     Geometry  2019-09-11 21:16:05
#
#                            post_content is_respondable_query notes
# 2    how do you a graph function rule?!              general   NaN
# 462                  is anybody there\n                  NaN   NaN
# 405     Wouldn't it be the same thing??                  NaN   NaN

# %%
adf.is_respondable_query.value_counts()
# Out:
# is_respondable_query
# problem                     62
# general                     52
# confirm                      8
# resource request             4
# general,problem              3
# advice                       2
# wrong but don't know why     1
# clarify question             1
# stuck                        1
# Name: count, dtype: int64

# %%
pd.crosstab(adf.subject_name, adf.is_respondable_query, margins=True).T.sort_values(by="All", ascending=False)
# Out:
# subject_name              6th Grade Math  Algebra 1  Geometry  Pre-Algebra  \
# is_respondable_query
# All                                    1        111        19            3
# problem                                1         54         7            0
# general                                0         40         9            3
# confirm                                0          6         2            0
# resource request                       0          3         1            0
# general,problem                        0          3         0            0
# advice                                 0          2         0            0
# clarify question                       0          1         0            0
# stuck                                  0          1         0            0
# wrong but don't know why               0          1         0            0
#
# subject_name              All
# is_respondable_query
# All                       134
# problem                    62
# general                    52
# confirm                     8
# resource request            4
# general,problem             3
# advice                      2
# clarify question            1
# stuck                       1
# wrong but don't know why    1

# %%
general_df = adf[adf.is_respondable_query.map(lambda s: pd.notna(s) and "general" in s)][
    ["post_id", "subject_name", "post_content", "is_respondable_query"]
]
general_df.sample(n=3)
# Out:
#      post_id subject_name                                       post_content  \
# 29    199138    Algebra 1  Can someone give me a factoring  example I don...
# 138  1105388  Pre-Algebra              Hey guys! What is the quotient rule??
# 110   859909    Algebra 1  How do you find the domain and range that are ...
#
#     is_respondable_query
# 29               general
# 138              general
# 110              general

# %%
general_df.to_csv(data_dir / "derived" / "mn_general_student_queries.csv", index=False)

# %%
# load the mathnation query data
mn_general_student_queries_filepath = data_dir / "derived" / "mn_general_student_queries.csv"
query_df = pd.read_csv(mn_general_student_queries_filepath)
print(f"MathNation queries: {query_df.shape}")
query_df.sample(n=3)
# Out:
# MathNation queries: (55, 4)
#     post_id subject_name                                       post_content  \
# 38  2672704    Algebra 1  i have a problem is this equation linear?\n7x ...
# 41  2690581    Algebra 1         How do you know if a number is a constant?
# 20  1790360    Algebra 1   What is vertex form and how do you solve for it?
#
#    is_respondable_query
# 38      general,problem
# 41              general
# 20              general
